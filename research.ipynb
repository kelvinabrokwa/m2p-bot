# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from cant_hide_money_bot.store import Store
from cant_hide_money_bot import std, book as book_lib

# %%
store = Store(std.Mode.DEV)
book = store.load_book()

# %%
book = book_lib.compute_shares_and_dollars(book)
book['abs_dollars'] = book['dollars'].apply(abs)

# %%
m2p_capital_guild_id = 738605371215839243
book = book[book['guild_id'] == m2p_capital_guild_id]

# %%
book
# Out:
#    symbol   dir   qty                       time    price         trader  \
# 2     XLK   BUY  1000 2021-01-04 10:25:50.888259   129.77       kel#6179
# 4    ARKF   BUY  1000 2021-01-04 10:34:43.207562    49.97       dux#8284
# 5     GME   BUY  5000 2021-01-04 10:38:10.152155    17.33  djruhnke#7977
# 6    PLUG   BUY   500 2021-01-04 10:39:00.055781    33.18    eileen#3348
# 7    XPEV  SELL  8156 2021-01-04 10:39:05.022806    46.62  djruhnke#7977
# ..    ...   ...   ...                        ...      ...            ...
# 76   ARKK   BUY   100 2021-02-12 22:27:39.324626   156.58       kel#6179
# 77    XLK  SELL  1000 2021-02-12 22:28:17.565631   138.59       kel#6179
# 78    IYR  SELL   100 2021-02-12 22:28:31.445740    89.54       kel#6179
# 81   GOOG   BUY     1 2021-02-12 23:42:22.963726 2,104.11       kel#6179
# 82   GOOG  SELL     1 2021-02-12 23:42:28.283947 2,104.11       kel#6179
#
#               guild_id  mult  shares              dollars         abs_dollars
# 2   738605371215839243     1    1000 -129,770.00000000001 129,770.00000000001
# 4   738605371215839243     1    1000            -49,970.0            49,970.0
# 5   738605371215839243     1    5000  -86,649.99999999999  86,649.99999999999
# 6   738605371215839243     1     500            -16,590.0            16,590.0
# 7   738605371215839243    -1   -8156           380,232.72          380,232.72
# ..                 ...   ...     ...                  ...                 ...
# 76  738605371215839243     1     100 -15,658.000000000002 15,658.000000000002
# 77  738605371215839243    -1   -1000            138,590.0           138,590.0
# 78  738605371215839243    -1    -100              8,954.0             8,954.0
# 81  738605371215839243     1       1            -2,104.11            2,104.11
# 82  738605371215839243    -1      -1             2,104.11            2,104.11
#
# [72 rows x 11 columns]

# %%
trades_by_trader = book.groupby('trader')

# %% [markdown]
# # Number of trades per trader

# %%
trades_by_trader.agg({'time': 'count'}).sort_values('time').plot.barh()
# Out:
# <AxesSubplot:ylabel='trader'>

# %% [markdown]
# # Average/median trade size by dollars traded

# %%
 trades_by_trader.agg({'abs_dollars': [np.mean, np.median]}).plot.barh()
# Out:
# <AxesSubplot:ylabel='trader'>

# %% [markdown]
# # Portfolio value over time

# %%
for trader, trades in trades_by_trader:
    plt.suptitle(trader)
    tick = matplotlib.ticker.StrMethodFormatter('${x:,.0f}')
    trades.plot(x='time', y='abs_dollars').get_yaxis().set_major_formatter(tick)
